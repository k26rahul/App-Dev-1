# %% [markdown]
# ![Untitled-2024-10-30-1044.png](attachment:Untitled-2024-10-30-1044.png)

# %%
class Product:
  _idx = 1

  def __init__(self, name, type):
    self.id = Product._idx
    Product._idx += 1

    self.name = name
    self.type = type

  def __repr__(self):
    return f'<Product {self.name}>'


class Stock:
  _idx = 1

  def __init__(self, product_id, qty, price, expiry):
    self.id = Stock._idx
    Stock._idx += 1

    self.product_id = product_id
    self.qty = qty
    self.price = price
    self.expiry = expiry

  def __repr__(self):
    return f'<Stock {self.product_id}>'

# %%
# products table as dict
products = {
    #: Product (as rows)
    1: Product('potato', 'veg'),
    2: Product('tomato', 'veg'),
    3: Product('milk', 'diary'),
    4: Product('honey', 'others'),
}

# stocks (inventory) table as dict
stocks = {
    #: Stock (as rows)
    1: Stock(product_id=1, qty=50, price=40, expiry=20),
    2: Stock(product_id=1, qty=150, price=20, expiry=5),
    3: Stock(product_id=4, qty=100, price=500, expiry=500)
}

# %%
def add_product(product):
  products[product.id] = product


add_product(Product('kiwi', 'fruit'))
add_product(Product('paddy', 'others'))
products
# Out:
# {1: <Product potato>,
#  2: <Product tomato>,
#  3: <Product milk>,
#  4: <Product honey>,
#  5: <Product kiwi>,
#  6: <Product paddy>}

# %%
def add_stock(stock):
  stocks[stock.id] = stock


add_stock(Stock(product_id=2, qty=100, price=60, expiry=10))
stocks
# Out:
# {1: <Stock 1>, 2: <Stock 1>, 3: <Stock 4>, 4: <Stock 2>}

# %%
stocks[3]  # what kind of <Stock> at slot=3

stocks[3].product_id  # product_id for that <Stock>

products[stocks[3].product_id]  # <Product> for that product_id

products[stocks[3].product_id].name  # name of that <Product>
# Out:
# <Stock 4>
# 4
# <Product honey>
# 'honey'
